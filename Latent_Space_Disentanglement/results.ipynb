# %% [markdown]
# # Reproducing the results
#
# ### Visualizing attention maps
# First we reproduce the attention maps for the baseline FactorVAE and the best performing AD-FactorVAE using $\lambda=40$ and the first convolutional layer. Press any key to close the image. (Using the --help flag you can find more options)

# %%
# !python visualizer.py --name FactorVAE --target_layer 0 --cuda --sample_count 10
# Out:
# loaded checkpoint 'checkpoints/FactorVAE'

# %%
# !python visualizer.py --name AD-FactorVAE --target_layer 0 --cuda --sample_count 10
# Out:
# loaded checkpoint 'checkpoints/AD-FactorVAE'

# %% [markdown]
# ### Plotting the results
# Next we plot the results for all the models used, the last one is the one used in the paper. (Using the --help flag you can find more options)

# %%
# %run plotter.py --names 'gamma40 lambda1_gamma40 lambda20_gamma40 lambda40_gamma40 conv3_lambda1_gamma40' --all_plots

# %%
cd FactorVAE
# Out:
# /home/frank/Desktop/Uni/FACT-AI/FactorVAE

# %%
ls
# Out:
# checkpoints/        environment.yml  model.py      README.md      solver.py
# data/               gradcam.py       ops.py        results/       utils.py
# dataset.py          LICENSE          plotter.py    results.ipynb  visualizer.py
# disentanglement.py  main.py          __pycache__/  scripts/
